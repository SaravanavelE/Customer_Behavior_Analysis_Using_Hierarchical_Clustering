# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
d=pd.read_csv("/content/drive/MyDrive/AI ML/2026/Technical/Datasets/Mall_Customers.csv")
d.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
le = LabelEncoder()
d['Genre'] = le.fit_transform(d['Genre'])
d.head()
# Out:
#    CustomerID  Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1      1   19                  15              39
# 1           2      1   21                  15              81
# 2           3      0   20                  16               6
# 3           4      0   23                  16              77
# 4           5      0   31                  17              40

# %%
d=d[['Annual_Income_(k$)','Spending_Score']]
d
# Out:
#      Annual_Income_(k$)  Spending_Score
# 0                    15              39
# 1                    15              81
# 2                    16               6
# 3                    16              77
# 4                    17              40
# ..                  ...             ...
# 195                 120              79
# 196                 126              28
# 197                 126              74
# 198                 137              18
# 199                 137              83
#
# [200 rows x 2 columns]

# %%
import scipy.cluster.hierarchy as sch
dend = sch.dendrogram(sch.linkage(d,method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
model= AgglomerativeClustering(n_clusters=5,metric='euclidean',linkage = 'average')
model.fit(d)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=5)

# %%
plt.figure(figsize=(15,7))
plt.scatter(d['Annual_Income_(k$)'],d['Spending_Score'],c=model.labels_)
plt.xlabel('Annual_Income_(k$)')
plt.ylabel('Spending_Score')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-3727257118.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from sklearn.cluster import DivisiveClustering
model= DivisiveClustering(n_clusters=5,metric='euclidean',linkage = 'ward')
model.fit(d)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-340045357.py in <cell line: 0>()
# ----> 1 from sklearn.cluster import DivisiveClustering
#       2 model= DivisiveClustering(n_clusters=5,metric='euclidean',linkage = 'ward')
#       3 model.fit(d)
#
# ImportError: cannot import name 'DivisiveClustering' from 'sklearn.cluster' (/usr/local/lib/python3.12/dist-packages/sklearn/cluster/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
